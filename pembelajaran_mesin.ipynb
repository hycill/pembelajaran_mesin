# %% [markdown]
# <a href="https://colab.research.google.com/github/hycill/pembelajaran_mesin/blob/main/pembelajaran_mesin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset = '/content/exercise_data (1).csv'

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#      distance  rhr  zone mins
# 0        4.69   69          0
# 1        3.26   69          7
# 2        9.05   69         59
# 3        7.88   65         80
# 4       10.00   63         67
# ..        ...  ...        ...
# 145      7.90   57          3
# 146      7.66   60         35
# 147      9.12   60         33
# 148      5.56   59         64
# 149      8.81   61         41
#
# [150 rows x 3 columns]

# %%
data.head()
# Out:
#    distance  rhr  zone mins
# 0      4.69   69          0
# 1      3.26   69          7
# 2      9.05   69         59
# 3      7.88   65         80
# 4     10.00   63         67

# %%
print(data.dtypes)
# Out:
# distance     float64
# rhr            int64
# zone mins      int64
# dtype: object

# %%
datanoid = data.drop(data.columns[2],axis=1)

# %%
datanoid
# Out:
#      distance  rhr
# 0        4.69   69
# 1        3.26   69
# 2        9.05   69
# 3        7.88   65
# 4       10.00   63
# ..        ...  ...
# 145      7.90   57
# 146      7.66   60
# 147      9.12   60
# 148      5.56   59
# 149      8.81   61
#
# [150 rows x 2 columns]

# %%
data.describe()
# Out:
#          distance         rhr   zone mins
# count  150.000000  150.000000  150.000000
# mean    10.354733   61.146667   69.073333
# std      4.300465    2.852967   60.331533
# min      1.950000   55.000000    0.000000
# 25%      7.422500   59.000000   13.250000
# 50%     10.095000   61.000000   59.000000
# 75%     13.485000   63.000000  108.750000
# max     26.310000   69.000000  276.000000

# %%
data.loc[:,"distance":].corr()
# Out:
#            distance       rhr  zone mins
# distance   1.000000 -0.400627   0.783972
# rhr       -0.400627  1.000000  -0.213426
# zone mins  0.783972 -0.213426   1.000000

# %%
# @title distance vs rhr

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='distance', y='rhr', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Dengan API

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-0e8f441a-c5d3-488a-b26a-c7efc93eaf58" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0e8f441a-c5d3-488a-b26a-c7efc93eaf58">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s 'personal exercise'
# Out:
# ...
# ref                                                             title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# suntzunami/personal-exercise-and-health-data                    Personal Exercise and Health Data                    957B  2024-02-27 06:25:08            497         22  1.0
# aroojanwarkhan/fitness-data-trends                              Fitness Trends Dataset                                1KB  2018-01-09 11:14:24           5852         76  0.7058824
# athniv/exercisepatternpredict                                   Exercise Pattern Prediction                           2MB  2017-04-05 22:44:00           2248         53  0.7058824
# ...

# %%
# !kaggle datasets download suntzunami/personal-exercise-and-health-data
# Out:
# ...
#   0% 0.00/957 [00:00<?, ?B/s]
# 100% 957/957 [00:00<00:00, 2.79MB/s]

# %%
# !unzip /content/personal-exercise-and-health-data.zip
# Out:
# Archive:  /content/personal-exercise-and-health-data.zip
# replace exercise_data.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
pd.read_csv('/content/exercise_data.csv')
# Out:
#      distance  rhr  zone mins
# 0        4.69   69          0
# 1        3.26   69          7
# 2        9.05   69         59
# 3        7.88   65         80
# 4       10.00   63         67
# ..        ...  ...        ...
# 145      7.90   57          3
# 146      7.66   60         35
# 147      9.12   60         33
# 148      5.56   59         64
# 149      8.81   61         41
#
# [150 rows x 3 columns]
